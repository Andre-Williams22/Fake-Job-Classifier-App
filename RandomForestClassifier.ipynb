# %% [markdown]
# ## Import Dependencies

# %%
# Standard Imports 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set()

# %% [markdown]
# ## 1. Get the Data Ready

# %%
## Import dataset 
df = pd.read_csv('Dataset/fake_job_postings.csv')
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df.sample(5)
# Out:
#        job_id                                              title  \
# 2562     2563                         Customer Service Associate
# 3409     3410                                    Digital Planner
# 8436     8437                                Completion Engineer
# 11410   11411  CM2 5AS Warehousing apprenticeship available u...
# 8387     8388                                     Java Developer
#
#                     location department salary_range  \
# 2562                      US        NaN          NaN
# 3409         NZ, N, Auckland   Strategy          NaN
# 8436   US, OK, Oklahoma City        NaN          NaN
# 11410       GB, , Chelmsford        NaN          NaN
# 8387       US, NJ, Teterboro        NaN          NaN
#
#                                          company_profile  \
# 2562                                                 NaN
# 3409   Young &amp; Shand is a full service digital ag...
# 8436   Valor Services provides Workforce Solutions th...
# ...

# %%
df.describe(include='all')
# Out:
#               job_id                    title         location department  \
# count   17880.000000                    17880            17534       6333
# unique           NaN                    11231             3105       1337
# top              NaN  English Teacher Abroad   GB, LND, London      Sales
# freq             NaN                      311              718        551
# mean     8940.500000                      NaN              NaN        NaN
# std      5161.655742                      NaN              NaN        NaN
# min         1.000000                      NaN              NaN        NaN
# 25%      4470.750000                      NaN              NaN        NaN
# 50%      8940.500000                      NaN              NaN        NaN
# 75%     13410.250000                      NaN              NaN        NaN
# max     17880.000000                      NaN              NaN        NaN
#
#        salary_range                                    company_profile  \
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow0_col1 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow0_col2 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow0_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow0_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow1_col0 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_eaa7cd10_81e0_11ea_a246_48bf6beebc3crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %%
# corr = df.corr()
# corr.style.background_gradient(cmap = 'coolwarm')

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
df.dtypes
# Out:
# job_id                  int64
# title                  object
# location               object
# department             object
# salary_range           object
# company_profile        object
# description            object
# requirements           object
# benefits               object
# telecommuting           int64
# has_company_logo        int64
# has_questions           int64
# employment_type        object
# required_experience    object
# required_education     object
# industry               object
# function               object
# fraudulent              int64
# dtype: object

# %%
df['department'].fillna('missing', inplace=True)
df['location'].fillna('missing', inplace=True)
df['description'].fillna('missing', inplace=True)
df['company_profile'].fillna('missing', inplace=True)
df['requirements'].fillna('missing', inplace=True)
df['benefits'].fillna('missing', inplace=True)
df['employment_type'].fillna('missing', inplace=True)
df['required_experience'].fillna('missing', inplace=True)
df['industry'].fillna('missing', inplace=True)
df['function'].fillna('missing', inplace=True)
df['required_education'].fillna('missing', inplace=True)

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                   0
# department                 0
# salary_range           15012
# company_profile            0
# description                0
# requirements               0
# benefits                   0
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type            0
# required_experience        0
# required_education         0
# industry                   0
# function                   0
# fraudulent                 0
# dtype: int64

# %%
# Remove rows with missing salary range values 
df.dropna(subset=['salary_range'], inplace=True)
